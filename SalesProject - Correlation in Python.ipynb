# %%
import pandas as pd
import seaborn as sns
import numpy as np

# %%
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import matplotlib
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %%
# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8)
pd.options.mode.chained_assignment = None

# %%
df = pd.read_csv(r'C:\Users\HP\Desktop\Sales.csv')
df
# Out:
#               Segment  Country    Product Discount Band  Units Sold  \
# 0          Government  Germany  Carretera           NaN      1513.0
# 1          Government  Germany      Paseo           NaN      1006.0
# 2          Government   Canada      Paseo           NaN      1725.0
# 3          Government  Germany      Paseo           NaN      1513.0
# 4          Government  Germany       Velo           NaN      1006.0
# ..                ...      ...        ...           ...         ...
# 695         Midmarket   Canada      Paseo          High      1614.0
# 696         Midmarket   Canada      Paseo          High      2559.0
# 697        Enterprise  Germany      Paseo          High      1085.0
# 698         Midmarket  Germany      Paseo          High      1175.0
# 699  Channel Partners      USA      Paseo          High       914.0
#
#      Sale Price      Sales      COGS     Profit       Date Month Name  Year
# ...

# %%
df.head()
# Out:
#       Segment  Country    Product Discount Band  Units Sold  Sale Price  \
# 0  Government  Germany  Carretera           NaN      1513.0         350
# 1  Government  Germany      Paseo           NaN      1006.0         350
# 2  Government   Canada      Paseo           NaN      1725.0         350
# 3  Government  Germany      Paseo           NaN      1513.0         350
# 4  Government  Germany       Velo           NaN      1006.0         350
#
#       Sales      COGS    Profit       Date Month Name  Year
# 0  529550.0  393380.0  136170.0  12/1/2014   December  2014
# 1  352100.0  261560.0   90540.0   6/1/2014       June  2014
# 2  603750.0  448500.0  155250.0  11/1/2013   November  2013
# 3  529550.0  393380.0  136170.0  12/1/2014   December  2014
# 4  352100.0  261560.0   90540.0   6/1/2014       June  2014

# %%
for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{} - {}%'.format(col, round(pct_missing*100)))
# Out:
# Segment - 0%
# Country - 0%
# Product - 0%
# Discount Band - 8%
# Units Sold - 0%
# Sale Price - 0%
# Sales - 0%
# COGS - 0%
# Profit - 0%
# Date - 0%
# Month Name - 0%
# Year - 0%

# %%
print(df.dtypes)
# Out:
# Segment           object
# Country           object
# Product           object
# Discount Band     object
# Units Sold       float64
# Sale Price         int64
# Sales            float64
# COGS             float64
# Profit           float64
# Date              object
# Month Name        object
# Year               int64
# dtype: object

# %%
df.boxplot(column = ['Profit'])
# Out:
# <Axes: >

# %%
df.drop_duplicates()
# Out:
#               Segment  Country    Product Discount Band  Units Sold  \
# 0          Government  Germany  Carretera           NaN      1513.0
# 1          Government  Germany      Paseo           NaN      1006.0
# 2          Government   Canada      Paseo           NaN      1725.0
# 3          Government  Germany      Paseo           NaN      1513.0
# 4          Government  Germany       Velo           NaN      1006.0
# ..                ...      ...        ...           ...         ...
# 695         Midmarket   Canada      Paseo          High      1614.0
# 696         Midmarket   Canada      Paseo          High      2559.0
# 697        Enterprise  Germany      Paseo          High      1085.0
# 698         Midmarket  Germany      Paseo          High      1175.0
# 699  Channel Partners      USA      Paseo          High       914.0
#
#      Sale Price      Sales      COGS     Profit       Date Month Name  Year
# ...

# %%
df.sort_values(by = ['Profit'], inplace= False, ascending = False)
# Out:
#         Segment  Country    Product Discount Band  Units Sold  Sale Price  \
# 24   Government      USA      Paseo           Low      3450.0         350
# 6    Government   France   Amarilla           NaN      2750.0         350
# 20   Government  Germany   Amarilla           Low      2966.0         350
# 15   Government  Germany       Velo           Low      2966.0         350
# 16   Government  Germany       Velo           Low      2877.0         350
# ..          ...      ...        ...           ...         ...         ...
# 577  Enterprise      USA       Velo          High      2438.0         125
# 553  Enterprise   Mexico  Carretera          High      2821.0         125
# 564  Enterprise      USA   Amarilla          High      2844.0         125
# 570  Enterprise  Germany  Carretera          High      2767.0         125
# 581  Enterprise   Canada        VTT          High      2954.0         125
#
#           Sales      COGS     Profit       Date Month Name  Year
# ...

# %%
sns.regplot(x = "Profit", y = "Sales", data=df)
# Out:
# <Axes: xlabel='Profit', ylabel='Sales'>

# %%
sns.regplot(x="COGS", y="Profit", data=df)
# Out:
# <Axes: xlabel='COGS', ylabel='Profit'>

# %%
print(df.dtypes)
# Out:
# Segment           object
# Country           object
# Product           object
# Discount Band     object
# Units Sold       float64
# Sale Price         int64
# Sales            float64
# COGS             float64
# Profit           float64
# Date              object
# Month Name        object
# Year               int64
# dtype: object

# %%
df['Units Sold'] = df['Units Sold'].astype(int
                                        )

# %%
df['Sales'] = df['Sales'].astype(int)
df['COGS'] = df['COGS'].astype(int)
df['Profit'] = df['Profit'].astype(int)
df.dtypes
# Out:
# Segment          object
# Country          object
# Product          object
# Discount Band    object
# Units Sold        int32
# Sale Price        int64
# Sales             int32
# COGS              int32
# Profit            int32
# Date             object
# Month Name       object
# Year              int64
# dtype: object

# %%
df.head()
# Out:
#       Segment  Country    Product Discount Band  Units Sold  Sale Price  \
# 0  Government  Germany  Carretera           NaN        1513         350
# 1  Government  Germany      Paseo           NaN        1006         350
# 2  Government   Canada      Paseo           NaN        1725         350
# 3  Government  Germany      Paseo           NaN        1513         350
# 4  Government  Germany       Velo           NaN        1006         350
#
#     Sales    COGS  Profit       Date Month Name  Year
# 0  529550  393380  136170  12/1/2014   December  2014
# 1  352100  261560   90540   6/1/2014       June  2014
# 2  603750  448500  155250  11/1/2013   November  2013
# 3  529550  393380  136170  12/1/2014   December  2014
# 4  352100  261560   90540   6/1/2014       June  2014

# %%
numeric_df = df.select_dtypes(include=[np.number])

# %%
numeric_df.corr()
# Out:
#             Units Sold    Sale Price     Sales      COGS    Profit  \
# Units Sold    1.000000 -6.506997e-02  0.326912  0.331693  0.228437
# Sale Price   -0.065070  1.000000e+00  0.805878  0.799335  0.650498
# Sales         0.326912  8.058779e-01  1.000000  0.992244  0.805464
# COGS          0.331693  7.993354e-01  0.992244  1.000000  0.725547
# Profit        0.228437  6.504977e-01  0.805464  0.725547  1.000000
# Year          0.063841  1.829362e-13  0.045554  0.047310  0.026634
#
#                     Year
# Units Sold  6.384106e-02
# Sale Price  1.829362e-13
# Sales       4.555384e-02
# COGS        4.731018e-02
# Profit      2.663402e-02
# Year        1.000000e+00

# %%
numeric_df.corr(method ='pearson')
# Out:
#             Units Sold    Sale Price     Sales      COGS    Profit  \
# Units Sold    1.000000 -6.506997e-02  0.326912  0.331693  0.228437
# Sale Price   -0.065070  1.000000e+00  0.805878  0.799335  0.650498
# Sales         0.326912  8.058779e-01  1.000000  0.992244  0.805464
# COGS          0.331693  7.993354e-01  0.992244  1.000000  0.725547
# Profit        0.228437  6.504977e-01  0.805464  0.725547  1.000000
# Year          0.063841  1.829362e-13  0.045554  0.047310  0.026634
#
#                     Year
# Units Sold  6.384106e-02
# Sale Price  1.829362e-13
# Sales       4.555384e-02
# COGS        4.731018e-02
# Profit      2.663402e-02
# Year        1.000000e+00

# %%
numeric_df.corr(method ='kendall')
# Out:
#             Units Sold  Sale Price     Sales      COGS    Profit      Year
# Units Sold    1.000000   -0.041420  0.299182  0.304243  0.213737  0.039519
# Sale Price   -0.041420    1.000000  0.706861  0.671113  0.389336  0.000000
# Sales         0.299182    0.706861  1.000000  0.883812  0.472613  0.022858
# COGS          0.304243    0.671113  0.883812  1.000000  0.356388  0.018189
# Profit        0.213737    0.389336  0.472613  0.356388  1.000000  0.023486
# Year          0.039519    0.000000  0.022858  0.018189  0.023486  1.000000

# %%
numeric_df.corr(method ='spearman')
# Out:
#             Units Sold  Sale Price     Sales      COGS    Profit      Year
# Units Sold    1.000000   -0.058793  0.375860  0.364901  0.295254  0.048343
# Sale Price   -0.058793    1.000000  0.869035  0.851726  0.524859  0.000000
# Sales         0.375860    0.869035  1.000000  0.971460  0.580817  0.027967
# COGS          0.364901    0.851726  0.971460  1.000000  0.473731  0.022253
# Profit        0.295254    0.524859  0.580817  0.473731  1.000000  0.028735
# Year          0.048343    0.000000  0.027967  0.022253  0.028735  1.000000

# %%
df.apply(lambda x: x.factorize()[0]).corr(method='pearson')
# Out:
#                     Segment       Country   Product  Discount Band  \
# Segment        1.000000e+00  4.018014e-16 -0.000336      -0.038611
# Country        4.018014e-16  1.000000e+00  0.018664       0.071049
# Product       -3.355495e-04  1.866376e-02  1.000000       0.003413
# Discount Band -3.861140e-02  7.104920e-02  0.003413       1.000000
# Units Sold     6.146604e-01  2.631503e-02 -0.074516       0.195872
# Sale Price     9.534626e-01  5.279997e-16 -0.007918      -0.038060
# Sales          6.862767e-01  9.144362e-03 -0.097642       0.226474
# COGS           6.861904e-01  2.116377e-02 -0.084936       0.220803
# Profit         6.867447e-01  1.408431e-02 -0.092265       0.235588
# Date           1.255983e-16 -6.193615e-18  0.023725       0.119136
# Month Name     1.191967e-16  2.149511e-17  0.020552       0.106458
# Year          -2.635923e-16 -6.733950e-18 -0.002032       0.021974
#
#                Units Sold    Sale Price     Sales      COGS    Profit  \
# ...

# %%
correlation_mat = df.apply(lambda x: x.factorize()[0]).corr()

corr_pairs = correlation_mat.unstack()

print(corr_pairs)
# Out:
# Segment  Segment          1.000000e+00
#          Country          4.018014e-16
#          Product         -3.355495e-04
#          Discount Band   -3.861140e-02
#          Units Sold       6.146604e-01
#                               ...
# Year     COGS            -1.910053e-02
#          Profit           2.996723e-03
#          Date            -9.341308e-02
#          Month Name      -1.901930e-01
#          Year             1.000000e+00
# Length: 144, dtype: float64

# %%
sorted_pairs = corr_pairs.sort_values(kind="quicksort")

print(sorted_pairs)
# Out:
# Month Name     Year            -0.190193
# Year           Month Name      -0.190193
# Product        Sales           -0.097642
# Sales          Product         -0.097642
# Year           Date            -0.093413
#                                   ...
# Discount Band  Discount Band    1.000000
# Product        Product          1.000000
# Country        Country          1.000000
# Month Name     Month Name       1.000000
# Year           Year             1.000000
# Length: 144, dtype: float64

# %%
strong_pairs = sorted_pairs[abs(sorted_pairs) > 0.5]

print(strong_pairs)
# Out:
# Segment        Units Sold       0.614660
# Units Sold     Segment          0.614660
# Month Name     Date             0.628289
# Date           Month Name       0.628289
# COGS           Segment          0.686190
# Segment        COGS             0.686190
#                Sales            0.686277
# Sales          Segment          0.686277
# Segment        Profit           0.686745
# Profit         Segment          0.686745
# Sale Price     Units Sold       0.727200
# Units Sold     Sale Price       0.727200
# COGS           Sale Price       0.796179
# Sale Price     COGS             0.796179
#                Sales            0.798006
# Sales          Sale Price       0.798006
# Sale Price     Profit           0.799521
# Profit         Sale Price       0.799521
# Units Sold     Profit           0.898734
# Profit         Units Sold       0.898734
# Units Sold     Sales            0.899215
# Sales          Units Sold       0.899215
# Units Sold     COGS             0.911390
# ...

# %%
ProductGrossSum = df.groupby('Product')[["Profit"]].sum()

ProductGrossSumSorted = ProductGrossSum.sort_values('Profit', ascending = False)[:5]

ProductGrossSumSorted
# Out:
#            Profit
# Product
# Paseo     4797382
# VTT       3034588
# Amarilla  2814085
# Velo      2305968
# Montana   2114726

# %%
df.groupby(['Product', 'Year'])[["Profit"]].sum()
# Out:
#                  Profit
# Product   Year
# Amarilla  2013   781943
#           2014  2032142
# Carretera 2013    38762
#           2014  1788023
# Montana   2013   457753
#           2014  1656973
# Paseo     2013  1099837
#           2014  3697545
# VTT       2013   878182
#           2014  2156406
# Velo      2013   621946
#           2014  1684022

# %%
ProductGrossSum = df.groupby(['Product', 'Year'])[["Profit"]].sum()

ProductGrossSumSorted = ProductGrossSum.sort_values(['Profit','Product','Year'], ascending = False)[:10]

ProductGrossSumSorted
# Out:
#                  Profit
# Product   Year
# Paseo     2014  3697545
# VTT       2014  2156406
# Amarilla  2014  2032142
# Carretera 2014  1788023
# Velo      2014  1684022
# Montana   2014  1656973
# Paseo     2013  1099837
# VTT       2013   878182
# Amarilla  2013   781943
# Velo      2013   621946

# %%
plt.scatter(x=df['Sales'], y=df['Profit'], alpha=0.5)
plt.title('Sales vs Profit')
plt.xlabel('Profit')
plt.ylabel('Sales')
plt.show()

# %%
df
# Out:
#               Segment  Country    Product Discount Band  Units Sold  \
# 0          Government  Germany  Carretera           NaN        1513
# 1          Government  Germany      Paseo           NaN        1006
# 2          Government   Canada      Paseo           NaN        1725
# 3          Government  Germany      Paseo           NaN        1513
# 4          Government  Germany       Velo           NaN        1006
# ..                ...      ...        ...           ...         ...
# 695         Midmarket   Canada      Paseo          High        1614
# 696         Midmarket   Canada      Paseo          High        2559
# 697        Enterprise  Germany      Paseo          High        1085
# 698         Midmarket  Germany      Paseo          High        1175
# 699  Channel Partners      USA      Paseo          High         914
#
#      Sale Price   Sales    COGS  Profit       Date Month Name  Year
# 0           350  529550  393380  136170  12/1/2014   December  2014
# ...

# %%
df_numerized = df


for col_name in df_numerized.columns:
    if(df_numerized[col_name].dtype == 'object'):
        df_numerized[col_name]= df_numerized[col_name].astype('category')
        df_numerized[col_name] = df_numerized[col_name].cat.codes
        
df_numerized
# Out:
#      Segment  Country  Product  Discount Band  Units Sold  Sale Price   Sales  \
# 0          2        2        1             -1        1513         350  529550
# 1          2        2        3             -1        1006         350  352100
# 2          2        0        3             -1        1725         350  603750
# 3          2        2        3             -1        1513         350  529550
# 4          2        2        5             -1        1006         350  352100
# ..       ...      ...      ...            ...         ...         ...     ...
# 695        3        0        3              0        1614          15   20578
# 696        3        0        3              0        2559          15   32627
# 697        1        2        3              0        1085         125  115281
# 698        3        2        3              0        1175          15   14981
# 699        0        4        3              0         914          12    9322
#
# ...

# %%
df_numerized.corr(method='pearson')
# Out:
#                     Segment       Country   Product  Discount Band  \
# Segment        1.000000e+00 -2.327008e-17  0.036000       0.037537
# Country       -2.327008e-17  1.000000e+00  0.005071       0.008187
# Product        3.600001e-02  5.070926e-03  1.000000       0.035021
# Discount Band  3.753711e-02  8.187007e-03  0.035021       1.000000
# Units Sold    -1.740335e-02 -7.831254e-02 -0.045357      -0.025728
# Sale Price     4.075107e-01 -7.436053e-17 -0.000182       0.032378
# Sales          3.234921e-01 -1.332510e-02  0.001659       0.024521
# COGS           3.349920e-01 -5.849067e-03  0.005960       0.018895
# Profit         1.937708e-01 -4.588282e-02 -0.019232       0.045667
# Date          -1.037663e-16 -7.812786e-19 -0.004293       0.024260
# Month Name     1.359083e-17 -5.093945e-17 -0.004690      -0.005760
# Year           9.364550e-14 -3.314165e-14 -0.005175      -0.050971
#
#                Units Sold    Sale Price     Sales      COGS    Profit  \
# ...

# %%
correlation_matrix = df_numerized.corr(method='pearson')

sns.heatmap(correlation_matrix, annot = True)

plt.title("Correlation Matrix for Sales Data")

plt.xlabel("Sales and Profit")

plt.ylabel("Sales and Profit")

plt.show()

# %%
for col_name in df.columns:
    if(df[col_name].dtype == 'object'):
        df[col_name]= df[col_name].astype('category')
        df[col_name] = df[col_name].cat.codes

# %%
df.head()
# Out:
#    Segment  Country  Product  Discount Band  Units Sold  Sale Price   Sales  \
# 0        2        2        1             -1        1513         350  529550
# 1        2        2        3             -1        1006         350  352100
# 2        2        0        3             -1        1725         350  603750
# 3        2        2        3             -1        1513         350  529550
# 4        2        2        5             -1        1006         350  352100
#
#      COGS  Profit  Date  Month Name  Year
# 0  393380  136170     6           2  2014
# 1  261560   90540    11           6  2014
# 2  448500  155250     3           9  2013
# 3  393380  136170     6           2  2014
# 4  261560   90540    11           6  2014

# %%
sns.swarmplot(x="Sale Price", y="Profit", data=df)
# Out:
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 66.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 13.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %%
sns.stripplot(x="Sale Price", y="Profit", data=df)
# Out:
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Sale Price', ylabel='Profit'>
